# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import kagglehub

# Download latest version
#path = kagglehub.dataset_download("cynthycynthy/titanicdataset")

#print("Path to dataset files:", path)

# %%
# leer el archivo csv descargado
# Use the path variable to read the CSV file

# df = pd.read_csv(path / "train.csv")

# %%
df0 = pd.read_csv('titanic.csv')

# %%
df0.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df0.shape
# Out:
# (891, 12)

# %%
# Display the DataFrame information
# This will show the number of entries, columns, and data types
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# extraer edad, genero y clase de pasajero
df0[['Age', 'Sex', 'Pclass']]
# Out:
#       Age     Sex  Pclass
# 0    22.0    male       3
# 1    38.0  female       1
# 2    26.0  female       3
# 3    35.0  female       1
# 4    35.0    male       3
# ..    ...     ...     ...
# 886  27.0    male       2
# 887  19.0  female       1
# 888   NaN  female       3
# 889  26.0    male       1
# 890  32.0    male       3
#
# [891 rows x 3 columns]

# %%
df_edad_sexo_pclass = df0[['Age','Sex','Pclass']]

# %%
df_edad_sexo_pclass.describe() # muestra estadisticas de las columnas numericas
# muestra estadisticas basicas de las columnas numericas
# como la edad, que es numerica, y las categoricas como sexo y clase de pasajero
# para las categoricas muestra el conteo de valores unicos, el valor mas frecuente y su frecuencia
# Out:
#               Age      Pclass
# count  714.000000  891.000000
# mean    29.699118    2.308642
# std     14.526497    0.836071
# min      0.420000    1.000000
# 25%     20.125000    2.000000
# 50%     28.000000    3.000000
# 75%     38.000000    3.000000
# max     80.000000    3.000000

# %%
# Filtrar los pasajeros mayores de 30 años
# This will create a new DataFrame with only those passengers
# whose 'Age' is greater than 30
above_30 = df_edad_sexo_pclass[df_edad_sexo_pclass['Age'] >= 30]
print(above_30)
# Out:
#       Age     Sex  Pclass
# 1    38.0  female       1
# 3    35.0  female       1
# 4    35.0    male       3
# 6    54.0    male       1
# 11   58.0  female       1
# ..    ...     ...     ...
# 873  47.0    male       3
# 879  56.0  female       1
# 881  33.0    male       3
# 885  39.0  female       3
# 890  32.0    male       3
#
# [330 rows x 3 columns]

# %%
# mayores de 30 años y sexo femenino
above_30_f = df_edad_sexo_pclass[(df_edad_sexo_pclass['Age'] > 30) & (df_edad_sexo_pclass['Sex'] == 'female')]
print(above_30_f)
# Out:
#       Age     Sex  Pclass
# 1    38.0  female       1
# 3    35.0  female       1
# 11   58.0  female       1
# 15   55.0  female       2
# 18   31.0  female       3
# ..    ...     ...     ...
# 862  48.0  female       1
# 865  42.0  female       2
# 871  47.0  female       1
# 879  56.0  female       1
# 885  39.0  female       3
#
# [103 rows x 3 columns]

# %%
# muestrame los valores unicos de la columna Sex
df_edad_sexo_pclass['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
above_30_f['Sex'].unique()
# Out:
# array(['female'], dtype=object)

# %%
df0.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# array is a list of values
# This will show the first 3 rows of the DataFrame
# This is useful for quickly checking the data
df0.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# array describes the first 5 rows of the DataFrame
df0.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# muestram la clases de los pasajeros 1 y 2
df0[df0['Pclass'].isin([1, 2])] 
# isin es un metodo que filtra los valores de una columna
# muestrame los pasajeros que no son de la clase 3
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# or 
# create a variable 
df0[(df0['Pclass'] ==1) | (df0['Pclass'] ==2)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# muestrame los no nulos de columna Age
#not null
df0['Age'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df_age_notna = df0[df0['Age'].notna()]
# notna es un metodo que filtra los valores no nulos de una columna

print(df_age_notna)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_age_notna.shape
# Out:
# (714, 12)

# %%
# nombre de los pasajeros mayores de 30 años
df_age_notna[df_age_notna['Age'] > 30]['Name']
print(df_age_notna[df_age_notna['Age'] > 30]['Name'])
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
#                              ...
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 881                                   Markun, Mr. Johann
# 885                 Rice, Mrs. William (Margaret Norton)
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 305, dtype: object

# %%
# loc es un metodo que permite acceder a las filas y columnas por su etiqueta
# muestrame los nombres de los pasajeros mayores de 30 años
df0.loc[df0['Age'] > 30, 'Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
#                              ...
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 881                                   Markun, Mr. Johann
# 885                 Rice, Mrs. William (Margaret Norton)
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 305, dtype: object

# %%
# agregar una nueva columna con el doble de la edad
df0['Double_Age'] = df0['Age'] * 2
df0.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age
# 0      0         A/5 21171   7.2500   NaN        S        44.0
# 1      0          PC 17599  71.2833   C85        C        76.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0

# %%
df0.shape
# Out:
# (891, 13)

# %%
# copia del DataFrame
df1 = df0.copy()
print(df1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# histograma de los pasajeros sobrevivientes
sns.histplot(data=df0, x='Age', hue='Survived', multiple='stack')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.countplot(x='Survived', data=df0)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Double_Age   714 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
891-714
# Out:
# 177

# %%
# quedan 177 pasajeros que no hay datos de edad
# como saber cuantos eran hombres y mujeres
df0[df0['Age'].isnull()]['Sex'].value_counts()
# Out:
# Sex
# male      124
# female     53
# Name: count, dtype: int64

# %%
# muestrame la edad de los pasajeros que no tienen datos de edad masculino
df0[df0['Age'].isnull() & (df0['Sex'] == 'male')]['Age']
# Out:
# 5     NaN
# 17    NaN
# 26    NaN
# 29    NaN
# 36    NaN
#        ..
# 839   NaN
# 846   NaN
# 859   NaN
# 868   NaN
# 878   NaN
# Name: Age, Length: 124, dtype: float64

# %%
# muestrame  la cantidad de los pasajeros que no tienen datos de edad femenino y que sobrevivieron
df0[df0['Age'].isnull() & (df0['Sex'] == 'female') & (df0['Survived'] == 1)].shape[0]
# Out:
# 36

# %%
# muestrame  la cantidad de los pasajeros que no tienen datos de edad femenino y que no sobrevivieron
df0[df0['Age'].isnull() & (df0['Sex'] == 'female') & (df0['Survived'] == 0)].shape[0]
# Out:
# 17

# %%
# muestrame la cantidad de los pasajeros que no tienen datos de edad masculino y que sobrevivieron
df0[df0['Age'].isnull() & (df0['Sex'] == 'male') & (df0['Survived'] == 1)].shape[0]
# Out:
# 16

# %%
# de los 16 pasajeros que no tienen datos de edad masculino, a que clase pertenecen
df0[df0['Age'].isnull() & (df0['Sex'] == 'male')]
df0[df0['Age'].isnull() & (df0['Sex'] == 'male')]['Pclass'].value_counts()
# Out:
# Pclass
# 3    94
# 1    21
# 2     9
# Name: count, dtype: int64

# %% [markdown]
# ### Pasajeros masculinos que sobrevivieron por clase

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad masculino, sobrevivieron y pertenece a la clase 1
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 1) & (df0['Survived'] == 1)].shape[0]
# Out:
# 5

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad masculino, sobrevivieron y pertenece a la clase 2
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 2) & (df0['Survived'] == 1)].shape[0]
# Out:
# 2

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad masculino, sobrevivieron y pertenece a la clase 3
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 3) & (df0['Survived'] == 1)].shape[0]
# Out:
# 9

# %% [markdown]
# ### pasajeros masculinos que no sobrevivieron por clase

# %%
# muestrame la cantidad de los pasajeros que no tienen datos de edad masculino y que no sobrevivieron
df0[df0['Age'].isnull() & (df0['Sex'] == 'male') & (df0['Survived'] == 0)].shape[0]
# Out:
# 108

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad masculino, y no sobrevivieron y pertenece a la clase 1
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 1) & (df0['Survived'] == 0)].shape[0]
# Out:
# 16

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad masculino, y no sobrevivieron y pertenece a la clase 2
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 2) & (df0['Survived'] == 0)].shape[0]
# Out:
# 7

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad masculino, y no sobrevivieron y pertenece a la clase 3
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 3) & (df0['Survived'] == 0)].shape[0]
# Out:
# 85

# %% [markdown]
# ### pasajeros femeninos que sobrevivieron por clase

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad femenino, sobrevivieron y pertenece a la clase 1
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 1) & (df0['Survived'] == 1)].shape[0]
# Out:
# 9

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad femenino, sobrevivieron y pertenece a la clase 2
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 2) & (df0['Survived'] == 1)].shape[0]
# Out:
# 2

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad femenino, sobrevivieron y pertenece a la clase 3
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 3) & (df0['Survived'] == 1)].shape[0]
# Out:
# 25

# %% [markdown]
# ### pasajeros femeninos que no sobrevivieron por clase

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad femenino, y no sobrevivieron y pertenece a la clase 1
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 1) & (df0['Survived'] == 0)].shape[0]
# Out:
# 0

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad femenino, y no sobrevivieron y pertenece a la clase 2
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 2) & (df0['Survived'] == 0)].shape[0]
# Out:
# 0

# %%
# muestrame los la cantidad de lo pasajeros que no tienen datos de edad femenino, y no sobrevivieron y pertenece a la clase 3
df0[(df0['Age'].isnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 3) & (df0['Survived'] == 0)].shape[0]
# Out:
# 17

# %%
df0.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Double_Age
# count  891.000000  891.000000  714.000000
# mean     0.381594   32.204208   59.398235
# std      0.806057   49.693429   29.052995
# min      0.000000    0.000000    0.840000
# 25%      0.000000    7.910400   40.250000
# 50%      0.000000   14.454200   56.000000
# 75%      0.000000   31.000000   76.000000
# ...

# %%
# muestrame el promedio de edad de los pasajeros masculinos
df0[df0['Sex'] == 'male']['Age'].mean()
# Out:
# np.float64(30.72664459161148)

# %%
# muestrame el promedio de edad de los pasajeros masculino que sobrevivieron
df0[(df0['Sex'] == 'male') & (df0['Survived'] == 1)]['Age'].mean()
# Out:
# np.float64(27.276021505376345)

# %%
# muestrame el promedio de edad de los pasajeros femeninos
df0[df0['Sex'] == 'female']['Age'].mean()
# Out:
# np.float64(27.915708812260537)

# %%
# muestrame el promedio y la cantidad de edad de los pasajeros masculinos que sobrevivieron en que clase viajaban
df0[(df0['Sex'] == 'male') & (df0['Survived'] == 1)].groupby('Pclass')['Age'].agg(['mean', 'count'])
# Out:
#              mean  count
# Pclass
# 1       36.248000     40
# 2       16.022000     15
# 3       22.274211     38

# %% [markdown]
# Categorias de edad completar
# 1. primera clase pasajeros masculinos que sobrevivieron
# 2.

# %%
# de los pasajeros masculinos que sobrevivieron, cuales no tienen datos de edad que estaban en primera clase
df_primera_clase=df0[(df0['Sex'] == 'male') & (df0['Survived'] == 1) & (df0['Age'].isnull()) & (df0['Pclass'] == 1)]

# %%
df_primera_clase.shape
# Out:
# (5, 13)

# %%
df_primera_clase.head()

# asignale la edad promedio de los pasajeros masculinos que sobrevivieron en primera clase a los que no tienen datos de edad
mean_age_male_survived_first_class = df0[(df0['Sex'] == 'male') & (df0['Survived'] == 1) & (df0['Pclass'] == 1)]['Age'].mean()
df_primera_clase['Age'] = df_primera_clase['Age'].fillna(mean_age_male_survived_first_class)
# Out:
# /var/folders/rs/ks5hqkqn4h1g1x9cm5vwy9nr0000gn/T/ipykernel_55613/1990925486.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_primera_clase['Age'] = df_primera_clase['Age'].fillna(mean_age_male_survived_first_class)

# %%
print(mean_age_male_survived_first_class)
# Out:
# 36.248000000000005

# %%
df_primera_clase.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 55            56         1       1
# 298          299         1       1
# 507          508         1       1
# 740          741         1       1
# 839          840         1       1
#
#                                               Name   Sex     Age  SibSp  \
# 55                               Woolner, Mr. Hugh  male  36.248      0
# 298                          Saalfeld, Mr. Adolphe  male  36.248      0
# 507  Bradley, Mr. George ("George Arthur Brayton")  male  36.248      0
# 740                    Hawksford, Mr. Walter James  male  36.248      0
# 839                           Marechal, Mr. Pierre  male  36.248      0
#
#      Parch  Ticket   Fare Cabin Embarked  Double_Age
# 55       0   19947  35.50   C52        S         NaN
# 298      0   19988  30.50  C106        S         NaN
# 507      0  111427  26.55   NaN        S         NaN
# 740      0   16988  30.00   D45        S         NaN
# ...

# %%
# muestrame el promedio de edad y la cantidad de los pasajeros masculinos que no sobrevivieron en que clase viajaban
df0[(df0['Sex'] == 'male') & (df0['Survived'] == 0)].groupby('Pclass')['Age'].agg(['mean', 'count'])
# Out:
#              mean  count
# Pclass
# 1       44.581967     61
# 2       33.369048     84
# 3       27.255814    215

# %%
# muestrame el promedio de edad y la cantidad de los pasajeros femenino que no sobrevivieron en que clase viajaban
df0[(df0['Sex'] == 'female') & (df0['Survived'] == 0)].groupby('Pclass')['Age'].agg(['mean', 'count'])
# Out:
#              mean  count
# Pclass
# 1       25.666667      3
# 2       36.000000      6
# 3       23.818182     55

# %% [markdown]
# ### Categorias de edades a completar
# 1. pasajeros que no tienen datos de edad masculino, sobrevivieron y pertenece a la clase 1- 5 (Hecho)
# 2. pasajeros que no tienen datos de edad masculino, sobrevivieron y pertenece a la clase 2 -2 (Hecho)
# 3. pasajeros que no tienen datos de edad masculino, sobrevivieron y pertenece a la clase 3- 9 (Hecho)
#
# ###
# 1. lo pasajeros que no tienen datos de edad masculino, y no sobrevivieron y pertenece a la clase 1 - 16 (Hecho)
# 2. pasajeros que no tienen datos de edad masculino, y no sobrevivieron y pertenece a la clase 2 - 7 (Hecho)
# 3. pasajeros que no tienen datos de edad masculino, y no sobrevivieron y pertenece a la clase 3 - 85 (Hecho)
#
# ### femenino
# 1. pasajeros que no tienen datos de edad femenino, sobrevivieron y pertenece a la clase 1-9(Hecho)
# 2. pasajeros que no tienen datos de edad femenino, sobrevivieron y pertenece a la clase 2-2 (Hecho)
# 3. pasajeros que no tienen datos de edad femenino, sobrevivieron y pertenece a la clase 3- 25 (Hecho)
#
# ###
# 1. lo pasajeros que no tienen datos de edad femenino, y no sobrevivieron y pertenece a la clase 1-0 (hecho)
# 2. lo pasajeros que no tienen datos de edad femenino, y no sobrevivieron y pertenece a la clase 2-0 (Hecho)
# 3. lo pasajeros que no tienen datos de edad femenino, y no sobrevivieron y pertenece a la clase 3-17 (Hecho)

# %%
# promedio de edad de los pasajeros masculinos sobrevivieron y pertenecen a la clase 1
mean_age_male_survived_first_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 1) & (df0['Survived'] == 1)]['Age'].mean()
mean_age_male_survived_first_class = round(mean_age_male_survived_first_class, 0)
print(mean_age_male_survived_first_class)
# Out:
# 36.0

# %%
# asignale mean_age_male_survived_first_class a la edad de los pasajeros masculinos sobrevivieron y pertenecen a la clase 1 en el df1
df1.loc[(df1['Sex'] == 'male') & (df1['Pclass'] == 1) & (df1['Survived'] == 1), 'Age'] = mean_age_male_survived_first_class

# %%
# promedio de edad de los pasajeros masculinos sobrevivieron y pertenecen a la clase 2
mean_age_male_survived_second_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 2) & (df0['Survived'] == 1)]['Age'].mean()
mean_age_male_survived_second_class = round(mean_age_male_survived_second_class, 0)
print(mean_age_male_survived_second_class)
# Out:
# 16.0

# %%
# asignale mean_age_male_survived_second_class a la edad de los pasajeros masculinos sobrevivieron y pertenecen a la clase 2 en el df1
df1.loc[(df1['Sex'] == 'male') & (df1['Pclass'] == 2) & (df1['Survived'] == 1), 'Age'] = mean_age_male_survived_second_class

# %%
# muestrame los pa

# %%
# muestrame los pasajeros masculinos que sobrevivieron y pertenecen a la clase 2
df1[(df1['Survived'] == 1) & (df1['Pclass'] == 2) & (df1['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 78            79         1       2    Caldwell, Master. Alden Gates  male
# 183          184         1       2        Becker, Master. Richard F  male
# 193          194         1       2       Navratil, Master. Michel M  male
# 226          227         1       2        Mellors, Mr. William John  male
# 288          289         1       2             Hosono, Mr. Masabumi  male
# 340          341         1       2   Navratil, Master. Edmond Roger  male
# 407          408         1       2   Richards, Master. William Rowe  male
# 543          544         1       2                Beane, Mr. Edward  male
# 547          548         1       2       Padro y Manent, Mr. Julian  male
# 549          550         1       2   Davies, Master. John Morgan Jr  male
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          721 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Double_Age   714 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
# promedio de edad de los pasajeros masculinos sobrevivieron y pertenecen a la clase 3
# df0[(df0['Age'].notnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 3) & (df0['Survived'] == 1)]['Age'].mean()
mean_age_male_survived_third_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 3) & (df0['Survived'] == 1)]['Age'].mean()
mean_age_male_survived_third_class = round(mean_age_male_survived_third_class, 0)
print(mean_age_male_survived_third_class)
# Out:
# 22.0

# %%
#muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 2 que edad es 33 del df0
df0[(df0['Age'] == 33) & (df0['Survived'] == 0) & (df0['Pclass'] == 2) & (df0['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 239          240         0       2  Hunt, Mr. George Henry  male  33.0      0
#
#      Parch      Ticket    Fare Cabin Embarked  Double_Age
# 239      0  SCO/W 1585  12.275   NaN        S        66.0

# %%
# asignale mean_age_male_survived_third_class a los pasajeros masculinos sobrevivieron y pertenecen a la clase 3 y que no tienen datas de edad en el df1
df1.loc[(df1['Age'].isnull()) & (df1['Survived'] == 1) & (df1['Pclass'] == 3) & (df1['Sex'] == 'male'), 'Age'] = mean_age_male_survived_third_class

# %%
#muestrame los pasajeros masculinos que sobrevivieron y pertenecen a la clase 3 que no tienen datos de edad del df1
df1[(df1['Age'].isnull()) & (df1['Survived'] == 1) & (df1['Pclass'] == 3) & (df1['Sex'] == 'male')]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Double_Age]
# Index: []

# %%
#muestrame los pasajeros masculinos que sobrevivieron y pertenecen a la clase 3 que tienen datos de edad del df1
# df1[(df1['Age'].notnull()) & (df1['Survived'] == 1) & (df1['Pclass'] == 3) & (df1['Sex'] == 'male')]

# %%
# promedio de edad de los pasajeros masculinos que no sobrevivieron en primera clase
mean_age_male_not_survived_first_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 1) & (df0['Survived'] == 0)]['Age'].mean()
mean_age_male_not_survived_first_class = round(mean_age_male_not_survived_first_class, 0)
print(mean_age_male_not_survived_first_class)
# Out:
# 45.0

# %%
# asignale mean_age_male_not_survived_first_class a los pasajeros masculinos que no sobrevivieron, pertenecen a la clase 1 y que no tienen datas de edad en el df1
df1.loc[(df1['Age'].isnull()) & (df1['Survived'] == 0) & (df1['Pclass'] == 1) & (df1['Sex'] == 'male'), 'Age'] = mean_age_male_not_survived_first_class

# %%
#muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 1 que su edad es de 45 del df1
# df1[(df1['Age'] == 45) & (df1['Survived'] == 0) & (df1['Pclass'] == 1) & (df1['Sex'] == 'male')]

# %%
# asignale mean_age_male_not_survived_second_class a los pasajeros masculinos que no sobrevivieron, pertenecen a la clase 2 y que no tienen datas de edad en el df1

# %%
# asignale mean

# %%
# promedio de edad de los pasajeros masculinos que no sobrevivieron en segunda clase
mean_age_male_not_survived_second_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 2) & (df0['Survived'] == 0)]['Age'].mean()
mean_age_male_not_survived_second_class = round(mean_age_male_not_survived_second_class, 0)
print(mean_age_male_not_survived_second_class)
# Out:
# 33.0

# %%
# asignale mean_age_male_not_survived_second_class a los pasajeros masculinos que no sobrevivieron, pertenecen a la clase 2 y que no tienen datas de edad en el df1
df1.loc[(df1['Age'].isnull()) & (df1['Survived'] == 0) & (df1['Pclass'] == 2) & (df1['Sex'] == 'male'), 'Age'] = mean_age_male_not_survived_second_class

# %%
#muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 2 del df1
df1[(df1['Age'] == 33) & (df1['Survived'] == 0) & (df1['Pclass'] == 2) & (df1['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 181          182         0       2                  Pernot, Mr. Rene  male
# 239          240         0       2            Hunt, Mr. George Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
#
#       Age  SibSp  Parch         Ticket    Fare Cabin Embarked  Double_Age
# 181  33.0      0      0  SC/PARIS 2131  15.050   NaN        C         NaN
# 239  33.0      0      0     SCO/W 1585  12.275   NaN        S        66.0
# ...

# %%
# promedio de edad de los pasajeros masculinos que no sobrevivieron en tercera clase
mean_age_male_not_survived_third_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'male') & (df0['Pclass'] == 3) & (df0['Survived'] == 0)]['Age'].mean()
mean_age_male_not_survived_third_class = round(mean_age_male_not_survived_third_class, 0)
print(mean_age_male_not_survived_third_class)
# Out:
# 27.0

# %%
# asignale mean_age_male_not_survived_third_class a los pasajeros masculinos que no sobrevivieron, pertenecen a la clase 3 y que no tienen datas de edad en el df1
df1.loc[(df1['Age'].isnull()) & (df1['Survived'] == 0) & (df1['Pclass'] == 3) & (df1['Sex'] == 'male'), 'Age'] = mean_age_male_not_survived_third_class

# %%
#muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 3 del df1
df1[(df1['Survived'] == 0) & (df1['Pclass'] == 3) & (df1['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 877          878         0       3            Petroff, Mr. Nedelio  male
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch           Ticket     Fare Cabin Embarked  Double_Age
# ...

# %%
# #muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 3 que la edad es de 27 del df1
df1[(df1['Age'] == 27) & (df1['Survived'] == 0) & (df1['Pclass'] == 3) & (df1['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 5              6         0       3             Moran, Mr. James  male  27.0
# 26            27         0       3      Emir, Mr. Farred Chehab  male  27.0
# 29            30         0       3          Todoroff, Mr. Lalio  male  27.0
# 42            43         0       3          Kraeff, Mr. Theodor  male  27.0
# 45            46         0       3     Rogers, Mr. William John  male  27.0
# ..           ...       ...     ...                          ...   ...   ...
# 837          838         0       3          Sirota, Mr. Maurice  male  27.0
# 846          847         0       3     Sage, Mr. Douglas Bullen  male  27.0
# 859          860         0       3             Razi, Mr. Raihed  male  27.0
# 868          869         0       3  van Melkebeke, Mr. Philemon  male  27.0
# 878          879         0       3           Laleff, Mr. Kristo  male  27.0
#
# ...

# %% [markdown]
# # Femenino promedio de edad

# %%
# promedio de edad de los pasajeros femenino sobrevivieron y pertenecen a la clase 1
mean_age_female_survived_first_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 1) & (df0['Survived'] == 1)]['Age'].mean()
mean_age_female_survived_first_class = round(mean_age_female_survived_first_class, 0)
print(mean_age_female_survived_first_class)
# Out:
# 35.0

# %%
# asignale mean_age_female_survived_first_class a los pasajeros femenino que  sobrevivieron, pertenecen a la clase 1 y que no tienen datas de edad en el df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 1) & (df1['Survived'] == 1) & (df1['Age'].isnull()), 'Age'] = mean_age_female_survived_first_class

# %%
#muestrame los pasajeros femenino que sobrevivieron y pertenecen a la clase 1 del df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 1) & (df1['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  35.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# promedio de edad de los pasajeros femenino sobrevivieron y pertenecen a la clase 2
mean_age_female_survived_second_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 2) & (df0['Survived'] == 1)]['Age'].mean()
mean_age_female_survived_second_class = round(mean_age_female_survived_second_class, 0)
print(mean_age_female_survived_second_class)
# Out:
# 28.0

# %%
# asignale mean_age_female_survived_second_class a los pasajeros femenino que  sobrevivieron, pertenecen a la clase 2 y que no tienen datas de edad en el df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 2) & (df1['Survived'] == 1) & (df1['Age'].isnull()), 'Age'] = mean_age_female_survived_second_class

# %%
#muestrame los pasajeros femenino que sobrevivieron y pertenecen a la clase 2 del df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 2) & (df1['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 43            44         1       2
# 53            54         1       2
# 56            57         1       2
# ..           ...       ...     ...
# 801          802         1       2
# 865          866         1       2
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 56                                   Rugg, Miss. Emily  female  21.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# promedio de edad de los pasajeros femenino sobrevivieron y pertenecen a la clase 3
mean_age_female_survived_third_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 3) & (df0['Survived'] == 1)]['Age'].mean()
mean_age_female_survived_third_class = round(mean_age_female_survived_third_class, 0)
print(mean_age_female_survived_third_class)
# Out:
# 19.0

# %%
# asignale mean_age_female_survived_third_class a los pasajeros femenino que  sobrevivieron, pertenecen a la clase 3 y que no tienen datas de edad en el df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 3) & (df1['Survived'] == 1) & (df1['Age'].isnull()), 'Age'] = mean_age_female_survived_third_class

# %%
#muestrame los pasajeros femenino que sobrevivieron y pertenecen a la clase 3 del df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 3) & (df1['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 823          824         1       3
# 830          831         1       3
# 855          856         1       3
# 858          859         1       3
# 875          876         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 19                             Masselmani, Mrs. Fatima  female  19.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# promedio de edad de los pasajeros femenino que no sobrevivieron en primera clase
mean_age_female_not_survived_first_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 1) & (df0['Survived'] == 0)]['Age'].mean()
mean_age_female_not_survived_first_class = round(mean_age_female_not_survived_first_class, 0)
print(mean_age_female_not_survived_first_class)
# Out:
# 26.0

# %%
# asignale mean_age_female_not_survived_first_class a los pasajeros femenino que no sobrevivieron, pertenecen a la clase 1 y que no tienen datas de edad en el df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 1) & (df1['Survived'] == 0) & (df1['Age'].isnull()), 'Age'] = mean_age_female_not_survived_first_class

# %%
#muestrame los pasajeros femenino que no sobrevivieron, pertenecen a la clase 1 y edad 26 en del df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 1) & (df1['Age'] == 26) & (df1['Survived'] == 0)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Double_Age]
# Index: []

# %%
# promedio de edad de los pasajeros femenino que no sobrevivieron en segunda clase
mean_age_female_not_survived_second_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 2) & (df0['Survived'] == 0)]['Age'].mean()
mean_age_female_not_survived_second_class = round(mean_age_female_not_survived_second_class, 0)
print(mean_age_female_not_survived_second_class)
# Out:
# 36.0

# %%
# asignale mean_age_female_not_survived_second_class a los pasajeros femenino que no sobrevivieron, pertenecen a la clase 2 y que no tienen datas de edad en el df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 2) & (df1['Survived'] == 0) & (df1['Age'].isnull()), 'Age'] = mean_age_female_not_survived_second_class

# %%
#muestrame los pasajeros femenino que no sobrevivieron, pertenecen a la clase 2 y edad 36 en del df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 2) & (df1['Age'] == 36) & (df1['Survived'] == 0)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Double_Age]
# Index: []

# %%
# promedio de edad de los pasajeros femenino que no sobrevivieron en tercera clase
mean_age_female_not_survived_third_class = df0[(df0['Age'].notnull()) & (df0['Sex'] == 'female') & (df0['Pclass'] == 3) & (df0['Survived'] == 0)]['Age'].mean()
mean_age_female_not_survived_third_class = round(mean_age_female_not_survived_third_class, 0)
print(mean_age_female_not_survived_third_class)
# Out:
# 24.0

# %%
# asignale mean_age_female_not_survived_third_class a los pasajeros femenino que no sobrevivieron, pertenecen a la clase 3 y que no tienen datas de edad en el df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 3) & (df1['Survived'] == 0) & (df1['Age'].isnull()), 'Age'] = mean_age_female_not_survived_third_class

# %%
#muestrame los pasajeros femenino que no sobrevivieron, pertenecen a la clase 3 y edad 24 en del df1
df1.loc[(df1['Sex'] == 'female') & (df1['Pclass'] == 3) & (df1['Age'] == 24) & (df1['Survived'] == 0)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 140          141         0       3             Boulos, Mrs. Joseph (Sultana)
# 180          181         0       3              Sage, Miss. Constance Gladys
# 229          230         0       3                   Lefebre, Miss. Mathilde
# 235          236         0       3              Harknett, Miss. Alice Phoebe
# 240          241         0       3                     Zabour, Miss. Thamine
# 264          265         0       3                        Henry, Miss. Delia
# 293          294         0       3                       Haas, Miss. Aloisia
# 409          410         0       3                        Lefebre, Miss. Ida
# 415          416         0       3   Meek, Mrs. Thomas (Annie Louise Rowley)
# 485          486         0       3                    Lefebre, Miss. Jeannie
# 502          503         0       3            O'Sullivan, Miss. Bridget Mary
# ...

# %%
#muestrame los pasajeros femenino que no sobrevivieron, pertenecen a la clase 3 y edad 24 en del df0
df0.loc[(df0['Sex'] == 'female') & (df0['Pclass'] == 3) & (df0['Age'] == 24) & (df0['Survived'] == 0)]
# Out:
#      PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 293          294         0       3  Haas, Miss. Aloisia  female  24.0      0
#
#      Parch  Ticket  Fare Cabin Embarked  Double_Age
# 293      0  349236  8.85   NaN        S        48.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Double_Age   714 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
# muestrame los pasajeros masculino que sobrevivieron y pertenecen a la clase 1 y 2 
df1[(df1['Survived'] == 1) & (df1['Pclass'].isin([1, 2])) & (df1['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# 78            79         1       2    Caldwell, Master. Alden Gates  male
# ..           ...       ...     ...                              ...   ...
# 827          828         1       2            Mallet, Master. Andre  male
# 831          832         1       2  Richards, Master. George Sibley  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch           Ticket     Fare Cabin Embarked  Double_Age
# ...

# %%
# muestrame la edad minima y maxima de los pasajeros
df1['Age'].agg(['min', 'max'])
# Out:
# min     0.42
# max    74.00
# Name: Age, dtype: float64

# %% [markdown]
# # Intervalo de confianza
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que sobrevivieron y pertenecen a la clase 1 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que sobrevivieron y pertenecen a la clase 2 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que sobrevivieron y pertenecen a la clase 3 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 1 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 2 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 3 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que sobrevivieron y pertenecen a la clase 1 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que sobrevivieron y pertenecen a la clase 2 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que sobrevivieron y pertenecen a la clase 3 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que no sobrevivieron y pertenecen a la clase 1 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que no sobrevivieron y pertenecen a la clase 2 del df0 (Hecho)
# #### muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que no sobrevivieron y pertenecen a la clase 3 del df0 (Hecho)

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que sobrevivieron y pertenecen a la clase 1 del df0
confidence_interval = df0.loc[(df0['Sex'] == 'male') & (df0['Survived'] == 1) & (df0['Pclass'] == 1), 'Age'].agg(['mean', 'std'])
confidence_interval['lower_bound'] = confidence_interval['mean'] - 1.96 * confidence_interval['std'] / np.sqrt(len(df0))
confidence_interval['upper_bound'] = confidence_interval['mean'] + 1.96 * confidence_interval['std'] / np.sqrt(len(df0))

print(confidence_interval)
# Out:
# mean           36.248000
# std            14.936744
# lower_bound    35.267217
# upper_bound    37.228783
# Name: Age, dtype: float64

# %%
df2=df0.copy()

# %%
# asignale un valor aleatorio entero entre 35 y 37 a los pasajeros masculino que sobrevivieron y pertenecen a la clase 1 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 1) & (df2['Age'].isnull()), 'Age'] = np.random.randint(35, 38, size=df2[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 1) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros masculinos que sobrevivieron y pertenecen a la clase 1 con edades entre 35 y 37 del df2
df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 1) & (df2['Age'].between(35, 37)), 'Age']
# Out:
# 55     36.0
# 248    37.0
# 298    36.0
# 390    36.0
# 507    35.0
# 512    36.0
# 572    36.0
# 604    35.0
# 679    36.0
# 701    35.0
# 737    35.0
# 740    37.0
# 839    35.0
# Name: Age, dtype: float64

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que sobrevivieron y pertenecen a la clase 2 del df0
confidence_interval_class2 = df0.loc[(df0['Sex'] == 'male') & (df0['Survived'] == 1) & (df0['Pclass'] == 2), 'Age'].agg(['mean', 'std'])
confidence_interval_class2['lower_bound'] = confidence_interval_class2['mean'] - 1.96 * confidence_interval_class2['std'] / np.sqrt(len(df0))
confidence_interval_class2['upper_bound'] = confidence_interval_class2['mean'] + 1.96 * confidence_interval_class2['std'] / np.sqrt(len(df0))

print(confidence_interval_class2)
# Out:
# mean           16.022000
# std            19.547122
# lower_bound    14.738488
# upper_bound    17.305512
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 14 y 17 a los pasajeros masculino que sobrevivieron y pertenecen a la clase 2 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 2) & (df2['Age'].isnull()), 'Age'] = np.random.randint(14, 18, size=df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 2) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros masculinos que sobrevivieron y pertenecen a la clase 2 con edades entre 14 y 17 del df2
df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 2) & (df2['Age'].between(14, 17)), :]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 17            18         1       2  Williams, Mr. Charles Eugene  male  14.0
# 547          548         1       2    Padro y Manent, Mr. Julian  male  15.0
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked  Double_Age
# 17       0      0         244373  13.0000   NaN        S         NaN
# 547      0      0  SC/PARIS 2146  13.8625   NaN        C         NaN

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que sobrevivieron y pertenecen a la clase 3 del df0
confidence_interval_class3 = df0.loc[(df0['Sex'] == 'male') & (df0['Survived'] == 1) & (df0['Pclass'] == 3), 'Age'].agg(['mean', 'std'])
confidence_interval_class3['lower_bound'] = confidence_interval_class3['mean'] - 1.96 * confidence_interval_class3['std'] / np.sqrt(len(df0))
confidence_interval_class3['upper_bound'] = confidence_interval_class3['mean'] + 1.96 * confidence_interval_class3['std'] / np.sqrt(len(df0))

print(confidence_interval_class3)
# Out:
# mean           22.274211
# std            11.555786
# lower_bound    21.515429
# upper_bound    23.032992
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 21 y 23 a los pasajeros masculino que sobrevivieron y pertenecen a la clase 3 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 3) & (df2['Age'].isnull()), 'Age'] = np.random.randint(21, 24, size=df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 3) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros masculinos que sobrevivieron y pertenecen a la clase 3 con edades entre 21 y 23 del df2

df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 1) & (df2['Pclass'] == 3) & (df2['Age'].between(21, 23)), :]
# Out:
#      PassengerId  Survived  Pclass  \
# 36            37         1       3
# 65            66         1       3
# 107          108         1       3
# 301          302         1       3
# 391          392         1       3
# 444          445         1       3
# 553          554         1       3
# 643          644         1       3
# 692          693         1       3
# 709          710         1       3
# 828          829         1       3
#
#                                                   Name   Sex   Age  SibSp  \
# 36                                    Mamee, Mr. Hanna  male  23.0      0
# 65                            Moubarek, Master. Gerios  male  22.0      1
# 107                             Moss, Mr. Albert Johan  male  22.0      0
# 301                                 McCoy, Mr. Bernard  male  21.0      2
# 391                             Jansson, Mr. Carl Olof  male  21.0      0
# 444                  Johannesen-Bratthammer, Mr. Bernt  male  22.0      0
# ...

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 1 del df0
confidence_interval_class1 = df0.loc[(df0['Sex'] == 'male') & (df0['Survived'] == 0) & (df0['Pclass'] == 1), 'Age'].agg(['mean', 'std'])
confidence_interval_class1['lower_bound'] = confidence_interval_class1['mean'] - 1.96 * confidence_interval_class1['std'] / np.sqrt(len(df0))
confidence_interval_class1['upper_bound'] = confidence_interval_class1['mean'] + 1.96 * confidence_interval_class1['std'] / np.sqrt(len(df0))

print(confidence_interval_class1)
# Out:
# mean           44.581967
# std            14.457749
# lower_bound    43.632636
# upper_bound    45.531299
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 43 y 45 a los pasajeros masculino que no sobrevivieron y pertenecen a la clase 1 y que no tienen datos de edad en el df2

df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 1) & (df2['Age'].isnull()), 'Age'] = np.random.randint(43, 46, size=df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 1) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 1 con edades entre 43 y 45 del df2

df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 1) & (df2['Age'].between(43, 45)), :]
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 62            63         0       1             Harris, Mr. Henry Birkhardt
# 64            65         0       1                   Stewart, Mr. Albert A
# 168          169         0       1                     Baumann, Mr. John D
# 185          186         0       1                   Rood, Mr. Hugh Roscoe
# 245          246         0       1             Minahan, Dr. William Edward
# 270          271         0       1                   Cairns, Mr. Alexander
# 284          285         0       1              Smith, Mr. Richard William
# 295          296         0       1                       Lewy, Mr. Ervin G
# 339          340         0       1            Blackwell, Mr. Stephen Weart
# 351          352         0       1  Williams-Lambert, Mr. Fletcher Fellows
# 475          476         0       1             Clifford, Mr. George Quincy
# ...

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 2 del df0

confidence_interval_class2not_surived = df0.loc[(df0['Sex'] == 'male') & (df0['Survived'] == 0) & (df0['Pclass'] == 2), 'Age'].agg(['mean', 'std'])
confidence_interval_class2not_surived['lower_bound'] = confidence_interval_class2not_surived['mean'] - 1.96 * confidence_interval_class2not_surived['std'] / np.sqrt(len(df0))
confidence_interval_class2not_surived['upper_bound'] = confidence_interval_class2not_surived['mean'] + 1.96 * confidence_interval_class2not_surived['std'] / np.sqrt(len(df0))

print(confidence_interval_class2not_surived)
# Out:
# mean           33.369048
# std            12.158125
# lower_bound    32.570715
# upper_bound    34.167380
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 32 y 34 a los pasajeros masculino que no sobrevivieron y pertenecen a la clase 2 y que no tienen datos de edad en el df2

df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 2) & (df2['Age'].isnull()), 'Age'] = np.random.randint(32, 35, size=df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 2) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 2 con edades entre 32 y 34 del df2

df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 2) & (df2['Age'].between(32, 34)), :]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 70            71         0       2        Jenkin, Mr. Stephen Curnow  male
# 99           100         0       2                 Kantor, Mr. Sinai  male
# 122          123         0       2              Nasser, Mr. Nicholas  male
# 181          182         0       2                  Pernot, Mr. Rene  male
# 239          240         0       2            Hunt, Mr. George Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 405          406         0       2                Gale, Mr. Shadrach  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 476          477         0       2           Renouf, Mr. Peter Henry  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# ...

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 3 del df0
confidence_interval_class3not_survived = df0.loc[(df0['Sex'] == 'male') & (df0['Survived'] == 0) & (df0['Pclass'] == 3), 'Age'].agg(['mean', 'std'])
confidence_interval_class3not_survived['lower_bound'] = confidence_interval_class3not_survived['mean'] - 1.96 * confidence_interval_class3not_survived['std'] / np.sqrt(len(df0))
confidence_interval_class3not_survived['upper_bound'] = confidence_interval_class3not_survived['mean'] + 1.96 * confidence_interval_class3not_survived['std'] / np.sqrt(len(df0))

print(confidence_interval_class3not_survived)
# Out:
# mean           27.255814
# std            12.135707
# lower_bound    26.458953
# upper_bound    28.052674
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 26 y 28 a los pasajeros masculino que no sobrevivieron y pertenecen a la clase 3 y que no tienen datos de edad en el df2

df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 3) & (df2['Age'].isnull()), 'Age'] = np.random.randint(26, 29, size=df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 3) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros masculinos que no sobrevivieron y pertenecen a la clase 3 con edades entre 26 y 28 del df2
df2.loc[(df2['Sex'] == 'male') & (df2['Survived'] == 0) & (df2['Pclass'] == 3) & (df2['Age'].between(26, 28)), :]
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 5              6         0       3             Moran, Mr. James  male  28.0
# 26            27         0       3      Emir, Mr. Farred Chehab  male  26.0
# 29            30         0       3          Todoroff, Mr. Lalio  male  28.0
# 42            43         0       3          Kraeff, Mr. Theodor  male  28.0
# 45            46         0       3     Rogers, Mr. William John  male  27.0
# ..           ...       ...     ...                          ...   ...   ...
# 846          847         0       3     Sage, Mr. Douglas Bullen  male  26.0
# 859          860         0       3             Razi, Mr. Raihed  male  26.0
# 868          869         0       3  van Melkebeke, Mr. Philemon  male  28.0
# 870          871         0       3            Balkic, Mr. Cerin  male  26.0
# 878          879         0       3           Laleff, Mr. Kristo  male  26.0
#
# ...

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros femenino que sobrevivieron y pertenecen a la clase 1 del df0

confidence_interval_class1female_survived = df0.loc[(df0['Sex'] == 'female') & (df0['Survived'] == 1) & (df0['Pclass'] == 1), 'Age'].agg(['mean', 'std'])
confidence_interval_class1female_survived['lower_bound'] = confidence_interval_class1female_survived['mean'] - 1.96 * confidence_interval_class1female_survived['std'] / np.sqrt(len(df0))
confidence_interval_class1female_survived['upper_bound'] = confidence_interval_class1female_survived['mean'] + 1.96 * confidence_interval_class1female_survived['std'] / np.sqrt(len(df0))

print(confidence_interval_class1female_survived)
# Out:
# mean           34.939024
# std            13.223014
# lower_bound    34.070769
# upper_bound    35.807280
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 34 y 35 a los pasajeros femenino que  sobrevivieron y pertenecen a la clase 1 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 1) & (df2['Age'].isnull()), 'Age'] = np.random.randint(34, 36, size=df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 1) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros femenino que  sobrevivieron y pertenecen a la clase 1 con edades entre 34 y 35 del df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 1) & (df2['Age'].between(34, 35)), ['Name', 'Age', 'Ticket']]
# Out:
#                                                   Name   Age    Ticket
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0    113803
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  35.0  PC 17569
# 166             Chibnall, Mrs. (Edith Martha Bowerman)  35.0    113505
# 230       Harris, Mrs. Henry Birkhardt (Irene Wallach)  35.0     36973
# 256                     Thorne, Mrs. Gertrude Maybelle  34.0  PC 17585
# 258                                   Ward, Miss. Anna  35.0  PC 17755
# 269                             Bissette, Miss. Amelia  35.0  PC 17760
# 306                            Fleming, Miss. Margaret  35.0     17421
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...  35.0  PC 17611
# 375              Meyer, Mrs. Edgar Joseph (Leila Saks)  34.0  PC 17604
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  35.0    113789
# 457                  Kenyon, Mrs. Frederick R (Marion)  35.0     17464
# ...

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros femenino que sobrevivieron y pertenecen a la clase 2 del df0

confidence_interval_class2female_survived = df0.loc[(df0['Sex'] == 'female') & (df0['Survived'] == 1) & (df0['Pclass'] == 2), 'Age'].agg(['mean', 'std'])
confidence_interval_class2female_survived['lower_bound'] = confidence_interval_class2female_survived['mean'] - 1.96 * confidence_interval_class2female_survived['std'] / np.sqrt(len(df0))
confidence_interval_class2female_survived['upper_bound'] = confidence_interval_class2female_survived['mean'] + 1.96 * confidence_interval_class2female_survived['std'] / np.sqrt(len(df0))

print(confidence_interval_class2female_survived)
# Out:
# mean           28.080882
# std            12.764693
# lower_bound    27.242721
# upper_bound    28.919044
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 27 y 28 a los pasajeros femenino que  sobrevivieron y pertenecen a la clase 2 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 2) & (df2['Age'].isnull()), 'Age'] = np.random.randint(27, 29, size=df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 2) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros femenino que sobrevivieron y pertenecen a la clase 2 con edades entre 27 y 28 del df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 2) & (df2['Age'].between(27, 28)), ['Name', 'Age', 'Ticket']]
# Out:
#                                             Name   Age         Ticket
# 303                          Keane, Miss. Nora A  28.0         226593
# 399             Trout, Mrs. William H (Jessie L)  28.0         240929
# 426  Clarke, Mrs. Charles V (Ada Maria Winfield)  28.0           2003
# 443                    Reynaldo, Ms. Encarnacion  28.0         230434
# 596                   Leitch, Miss. Jessie Wills  28.0         248727
# 635                            Davis, Miss. Mary  28.0         237668
# 717          Troutt, Miss. Edwina Celia "Winnie"  27.0          34218
# 866                 Duran y More, Miss. Asuncion  27.0  SC/PARIS 2149
# 874        Abelson, Mrs. Samuel (Hannah Wizosky)  28.0      P/PP 3381

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros femenino que sobrevivieron y pertenecen a la clase 3 del df0

confidence_interval_class3female_survived = df0.loc[(df0['Sex'] == 'female') & (df0['Survived'] == 1) & (df0['Pclass'] == 3), 'Age'].agg(['mean', 'std'])
confidence_interval_class3female_survived['lower_bound'] = confidence_interval_class3female_survived['mean'] - 1.96 * confidence_interval_class3female_survived['std'] / np.sqrt(len(df0))
confidence_interval_class3female_survived['upper_bound'] = confidence_interval_class3female_survived['mean'] + 1.96 * confidence_interval_class3female_survived['std'] / np.sqrt(len(df0))

print(confidence_interval_class3female_survived)
# Out:
# mean           19.329787
# std            12.303246
# lower_bound    18.521926
# upper_bound    20.137649
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 18 y 20 a los pasajeros femenino que  sobrevivieron y pertenecen a la clase 3 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 3) & (df2['Age'].isnull()), 'Age'] = np.random.randint(18, 21, size=df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 3) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros femenino que  sobrevivieron y pertenecen a la clase 3 con edades entre 18 y 20 del df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 1) & (df2['Pclass'] == 3) & (df2['Age'].between(18, 20)), ['Name', 'Age', 'Ticket']]
# Out:
#                                                   Name   Age   Ticket
# 19                             Masselmani, Mrs. Fatima  20.0     2649
# 28                       O'Dwyer, Miss. Ellen "Nellie"  20.0   330959
# 32                            Glynn, Miss. Mary Agatha  18.0   335677
# 44                       Devaney, Miss. Margaret Delia  19.0   330958
# 47                           O'Driscoll, Miss. Bridget  19.0    14311
# 82                      McDermott, Miss. Brigdet Delia  18.0   330932
# 109                                Moran, Miss. Bertha  20.0   371110
# 128                                  Peter, Miss. Anna  20.0     2668
# 186    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  19.0   370365
# 192    Andersen-Jensen, Miss. Carla Christine Nielsine  19.0   350046
# 198                   Madigan, Miss. Margaret "Maggie"  20.0   370370
# 241                     Murphy, Miss. Katherine "Kate"  18.0   367230
# ...

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que no sobrevivieron y pertenecen a la clase 1 del df0 

confidence_interval_class1female_not_survived = df0.loc[(df0['Sex'] == 'female') & (df0['Survived'] == 0) & (df0['Pclass'] == 1), 'Age'].agg(['mean', 'std'])
confidence_interval_class1female_not_survived['lower_bound'] = confidence_interval_class1female_not_survived['mean'] - 1.96 * confidence_interval_class1female_not_survived['std'] / np.sqrt(len(df0))
confidence_interval_class1female_not_survived['upper_bound'] = confidence_interval_class1female_not_survived['mean'] + 1.96 * confidence_interval_class1female_not_survived['std'] / np.sqrt(len(df0))

print(confidence_interval_class1female_not_survived)
# Out:
# mean           25.666667
# std            24.006943
# lower_bound    24.090311
# upper_bound    27.243022
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 24 y 27 a los pasajeros femenino que no sobrevivieron y pertenecen a la clase 1 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 1) & (df2['Age'].isnull()), 'Age'] = np.random.randint(24, 28, size=df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 1) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros femenino que no sobrevivieron y pertenecen a la clase 1 con edades entre 24 y 27 del df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 1) & (df2['Age'].between(24, 27)), ['Name', 'Age', 'Ticket']]
# Out:
#                                                 Name   Age  Ticket
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0  113781

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que no sobrevivieron y pertenecen a la clase 2 del df0 
confidence_interval_class2female_not_survived = df0.loc[(df0['Sex'] == 'female') & (df0['Survived'] == 0) & (df0['Pclass'] == 2), 'Age'].agg(['mean', 'std'])
confidence_interval_class2female_not_survived['lower_bound'] = confidence_interval_class2female_not_survived['mean'] - 1.96 * confidence_interval_class2female_not_survived['std'] / np.sqrt(len(df0))
confidence_interval_class2female_not_survived['upper_bound'] = confidence_interval_class2female_not_survived['mean'] + 1.96 * confidence_interval_class2female_not_survived['std'] / np.sqrt(len(df0))

print(confidence_interval_class2female_not_survived)
# Out:
# mean           36.000000
# std            12.915107
# lower_bound    35.151962
# upper_bound    36.848038
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 35 y 36 a los pasajeros femenino que no sobrevivieron y pertenecen a la clase 2 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 2) & (df2['Age'].isnull()), 'Age'] = np.random.randint(35, 37, size=df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 2) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros femenino que no sobrevivieron y pertenecen a la clase 2 con edades entre 35 y 36 del df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 2) & (df2['Age'].between(35, 36)), ['Name', 'Age', 'Ticket']]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Ticket]
# Index: []

# %%
# muestrame el intervalo de confianza del 95% de la edad de los pasajeros femeninos que no sobrevivieron y pertenecen a la clase 3 del df0 
confidence_interval_class3female_not_survived = df0.loc[(df0['Sex'] == 'female') & (df0['Survived'] == 0) & (df0['Pclass'] == 3), 'Age'].agg(['mean', 'std'])
confidence_interval_class3female_not_survived['lower_bound'] = confidence_interval_class3female_not_survived['mean'] - 1.96 * confidence_interval_class3female_not_survived['std'] / np.sqrt(len(df0))
confidence_interval_class3female_not_survived['upper_bound'] = confidence_interval_class3female_not_survived['mean'] + 1.96 * confidence_interval_class3female_not_survived['std'] / np.sqrt(len(df0))

print(confidence_interval_class3female_not_survived)
# Out:
# mean           23.818182
# std            12.833465
# lower_bound    22.975505
# upper_bound    24.660859
# Name: Age, dtype: float64

# %%
# asignale un valor aleatorio entero entre 22 y 24 a los pasajeros femenino que no sobrevivieron y pertenecen a la clase 3 y que no tienen datos de edad en el df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 3) & (df2['Age'].isnull()), 'Age'] = np.random.randint(22, 25, size=df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 3) & (df2['Age'].isnull())].shape[0])

# %%
# muestrame los pasajeros femenino que no sobrevivieron y pertenecen a la clase 3 con edades entre 22 y 24 del df2
df2.loc[(df2['Sex'] == 'female') & (df2['Survived'] == 0) & (df2['Pclass'] == 3) & (df2['Age'].between(22, 24)), ['Name', 'Age', 'Ticket']]
# Out:
#                                          Name   Age             Ticket
# 140             Boulos, Mrs. Joseph (Sultana)  22.0               2678
# 180              Sage, Miss. Constance Gladys  22.0           CA. 2343
# 229                   Lefebre, Miss. Mathilde  24.0               4133
# 235              Harknett, Miss. Alice Phoebe  24.0         W./C. 6609
# 240                     Zabour, Miss. Thamine  24.0               2665
# 264                        Henry, Miss. Delia  24.0             382649
# 293                       Haas, Miss. Aloisia  24.0             349236
# 409                        Lefebre, Miss. Ida  22.0               4133
# 415   Meek, Mrs. Thomas (Annie Louise Rowley)  24.0             343095
# 474               Strandberg, Miss. Ida Sofia  22.0               7553
# 485                    Lefebre, Miss. Jeannie  23.0               4133
# 502            O'Sullivan, Miss. Bridget Mary  22.0             330909
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Double_Age   714 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   891 non-null    int64
#  1   Survived      891 non-null    int64
#  2   Pclass        891 non-null    int64
#  3   Name          891 non-null    object
#  4   Sex           891 non-null    object
#  5   Age           891 non-null    int64
#  6   SibSp         891 non-null    int64
#  7   Parch         891 non-null    int64
#  8   Ticket        891 non-null    object
#  9   Fare          891 non-null    float64
#  10  Cabin         204 non-null    object
#  11  Embarked      889 non-null    object
#  12  Double_Age    714 non-null    float64
#  13  Age_category  891 non-null    object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 97.6+ KB

# %%
# convertir a entero la columna Age del df1
# df1['Age'] = df1['Age'].astype('Int64')

# %%
# convertir la columna Age a tipo entero con el metodo apply
df1['Age'] = df1['Age'].apply(lambda x: int(x) if pd.notnull(x) else x)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   891 non-null    int64
#  1   Survived      891 non-null    int64
#  2   Pclass        891 non-null    int64
#  3   Name          891 non-null    object
#  4   Sex           891 non-null    object
#  5   Age           891 non-null    int64
#  6   SibSp         891 non-null    int64
#  7   Parch         891 non-null    int64
#  8   Ticket        891 non-null    object
#  9   Fare          891 non-null    float64
#  10  Cabin         204 non-null    object
#  11  Embarked      889 non-null    object
#  12  Double_Age    714 non-null    float64
#  13  Age_category  891 non-null    object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 97.6+ KB

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age Age_category
# 0      0         A/5 21171   7.2500   NaN        S        44.0       Adulto
# 1      0          PC 17599  71.2833   C85        C        76.0       Adulto
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0       Adulto
# ...

# %%
# crear una columna con una copia de la columna Age
df1['Age_category'] = df1['Age'].copy()

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age  Age_category
# 0      0         A/5 21171   7.2500   NaN        S        44.0            22
# 1      0          PC 17599  71.2833   C85        C        76.0            38
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0            26
# ...

# %%
# definir una funcion de rango de edad para niños, adultos y ancianos
def age_category(age):
    if age < 18:
        return 'Niño'
    elif 18 <= age < 65:
        return 'Adulto'
    else:
        return 'Anciano'

# %%
# aplica la funcion age_category a la columna Age_category
df1['Age_category'] = df1['Age_category'].apply(age_category)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age Age_category
# 0      0         A/5 21171   7.2500   NaN        S        44.0       Adulto
# 1      0          PC 17599  71.2833   C85        C        76.0       Adulto
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0       Adulto
# ...

# %%
# totaliza la categoria de edad por sexo y clase
age_category_counts = df1.groupby(['Age_category', 'Sex', 'Pclass']).size().reset_index(name='Counts')
print(age_category_counts)
# Out:
#    Age_category     Sex  Pclass  Counts
# 0        Adulto  female       1      86
# 1        Adulto  female       2      64
# 2        Adulto  female       3     109
# 3        Adulto    male       1     117
# 4        Adulto    male       2      87
# 5        Adulto    male       3     301
# 6       Anciano    male       1       5
# 7       Anciano    male       2       2
# 8       Anciano    male       3       3
# 9          Niño  female       1       8
# 10         Niño  female       2      12
# 11         Niño  female       3      35
# 12         Niño    male       2      19
# 13         Niño    male       3      43

# %%
# muestrame una grafica de barras apiladas de la categoria de edad por sexo y clase
plt.figure(figsize=(10, 6))
sns.barplot(data=age_category_counts, x='Age_category', y='Counts', hue='Sex', ci=None)
plt.title('Distribución de la categoría de edad por sexo')
plt.xlabel('Categoría de Edad')
plt.ylabel('Cantidad')
plt.legend(title='Sexo')
plt.show()
# Out:
# /var/folders/rs/ks5hqkqn4h1g1x9cm5vwy9nr0000gn/T/ipykernel_55613/2777513479.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=age_category_counts, x='Age_category', y='Counts', hue='Sex', ci=None)

# %% [markdown]
# 1. ¿Cómo se relaciona el precio pagado en relación al promedio de su clase con la probabilidad de supervivencia?
#
# 2.  ¿Los pasajeros con familias inusualmente grandes (percentil 95+) tuvieron diferente tasa de supervivencia comparados con familias promedio?
#
# 3. ¿Cómo modifica la clase social el efecto protector de la edad joven en la supervivencia?
#
# 4. ¿Existen diferencias en las tasas de supervivencia entre puertos de embarque que no pueden explicarse por diferencias en composición de clase?
#
# 5. ¿Cómo difiere la supervivencia entre padres viajando con hijos vs hijos viajando con padres?
#
# 6. ¿Existen pasajeros con tarifas extremadamente altas o bajas para su clase que muestren patrones de supervivencia inusuales?
#
# 7. ¿Cómo cambia la ventaja de supervivencia femenina en diferentes grupos de edad?
#
# 8. ¿Los pasajeros en cubiertas superiores (identificadas por letra de cabina) tuvieron mayor probabilidad de supervivencia?
#
# 9. ¿Las familias completas tuvieron mayor probabilidad de supervivencia que miembros individuales de familias?
#
# 10. ¿Qué grupo demográfico representó el mejor 'valor' en términos de costo por vida salvada?

# %%
# muestrame la relacion entre el precio pagado de tarifas por pasajeros y la probabilidad de supervivencia del df2
df2['Fare'].groupby(df2['Survived']).describe()
# Out:
#           count       mean        std  min      25%   50%   75%       max
# Survived
# 0         549.0  22.117887  31.388207  0.0   7.8542  10.5  26.0  263.0000
# 1         342.0  48.395408  66.596998  0.0  12.4750  26.0  57.0  512.3292

# %%
# muestrame un grafica con la relacion entre el precio pagado de tarifas por pasajeros y la probabilidad de supervivencia del df2
plt.figure(figsize=(10, 6))
sns.boxplot(x='Survived', y='Fare', data=df2)
plt.title('Relación entre el precio de tarifas y la probabilidad de supervivencia')
plt.xlabel('Supervivencia (0 = No, 1 = Sí)')
plt.ylabel('Precio de Tarifas')
plt.show()

# %%
# muestrame el total de pasajeros que no sobrevivieron
total_not_survived = df2[df2['Survived'] == 0].shape[0]
print(f'Total de pasajeros que no sobrevivieron: {total_not_survived}')
# Out:
# Total de pasajeros que no sobrevivieron: 549

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.302099    0.523008
# std     257.353842    0.486592    0.836071   13.375489    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   21.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   36.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Double_Age
# count  891.000000  891.000000  714.000000
# mean     0.381594   32.204208   59.398235
# std      0.806057   49.693429   29.052995
# min      0.000000    0.000000    0.840000
# 25%      0.000000    7.910400   40.250000
# 50%      0.000000   14.454200   56.000000
# 75%      0.000000   31.000000   76.000000
# ...

# %%
# 1. ¿Cómo se relaciona el precio pagado en relación al promedio de su clase con la probabilidad de supervivencia?
df2['Fare'].groupby([df2['Pclass'], df2['Survived']]).mean()
# Out:
# Pclass  Survived
# 1       0           64.684007
#         1           95.608029
# 2       0           19.412328
#         1           22.055700
# 3       0           13.669364
#         1           13.694887
# Name: Fare, dtype: float64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Double_Age   714 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
# muestrame la cantidad de padres que tenian los pasajeros
df2['Parch'].value_counts()

# %%
df2[['Parch','SibSp']].describe()
# Out:
#             Parch       SibSp
# count  891.000000  891.000000
# mean     0.381594    0.523008
# std      0.806057    1.102743
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.000000    1.000000
# max      6.000000    8.000000

# %%
# 2.  ¿Los pasajeros con familias inusualmente grandes (percentil 95+) tuvieron diferente tasa de supervivencia comparados con familias promedio?
df2['FamilySize'] = df2['SibSp'] + df2['Parch'] + 1
df2['FamilySizeCategory'] = pd.cut(df2['FamilySize'], bins=[0, 1, 2, 3, 4, 5, 6, 7, 8,], labels=['Solo', 'Pequeña', 'Promedio', 'Grande', 'Muy Grande', 'Enorme', 'Gigante', 'Colosal'])

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age  FamilySize  \
# 0      0         A/5 21171   7.2500   NaN        S        44.0           2
# 1      0          PC 17599  71.2833   C85        C        76.0           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0           1
# ...

# %%
# muestrame la taza de superviviencia por categoria de tamaño de familia
family_survival_rate = df2.groupby('FamilySizeCategory')['Survived'].mean().reset_index()
print(family_survival_rate)
# Out:
#   FamilySizeCategory  Survived
# 0               Solo  0.303538
# 1            Pequeña  0.552795
# 2           Promedio  0.578431
# 3             Grande  0.724138
# 4         Muy Grande  0.200000
# 5             Enorme  0.136364
# 6            Gigante  0.333333
# 7            Colosal  0.000000
# /var/folders/rs/ks5hqkqn4h1g1x9cm5vwy9nr0000gn/T/ipykernel_55613/1999525575.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   family_survival_rate = df2.groupby('FamilySizeCategory')['Survived'].mean().reset_index()

# %%
# puedes hacer una grafica de barras para visualizar la taza de superviviencia por categoria de tamaño de familia
plt.figure(figsize=(10, 6))
sns.barplot(data=family_survival_rate, x='FamilySizeCategory', y='Survived', ci=None)
plt.title('Tasa de Supervivencia por Categoría de Tamaño de Familia')
plt.xlabel('Categoría de Tamaño de Familia')
plt.ylabel('Tasa de Supervivencia')
plt.ylim(0, 1)
plt.show()
# Out:
# /var/folders/rs/ks5hqkqn4h1g1x9cm5vwy9nr0000gn/T/ipykernel_55613/1322143030.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=family_survival_rate, x='FamilySizeCategory', y='Survived', ci=None)

# %%
# totaliza la cantidad de familias por su tamaño
family_size_counts = df2['FamilySizeCategory'].value_counts().reset_index()
family_size_counts.columns = ['FamilySizeCategory', 'Count']
print(family_size_counts)
# Out:
#   FamilySizeCategory  Count
# 0               Solo    537
# 1            Pequeña    161
# 2           Promedio    102
# 3             Grande     29
# 4             Enorme     22
# 5         Muy Grande     15
# 6            Gigante     12
# 7            Colosal      6

# %%
# De las 29 familias grande todas sobrevivieron?
large_family_survival = df2[df2['FamilySizeCategory'] == 'Grande']['Survived'].sum()
print(f"Total de familias grandes: 29")
print(f"Total de sobrevivientes en familias grandes: {large_family_survival}")
# Out:
# Total de familias grandes: 29
# Total de sobrevivientes en familias grandes: 21

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age Age_category
# 0      0         A/5 21171   7.2500   NaN        S        44.0       Adulto
# 1      0          PC 17599  71.2833   C85        C        76.0       Adulto
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0       Adulto
# ...

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age  FamilySize  \
# 0      0         A/5 21171   7.2500   NaN        S        44.0           2
# 1      0          PC 17599  71.2833   C85        C        76.0           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0           1
# ...

# %%
# agrega el atributo Age_category al df2
df2['Age_category'] = df1['Age_category']

df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Double_Age  FamilySize  \
# 0      0         A/5 21171   7.2500   NaN        S        44.0           2
# 1      0          PC 17599  71.2833   C85        C        76.0           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0           1
# ...

# %%
# 3. ¿Cómo modifica la clase social el efecto protector de la edad joven en la supervivencia?
age_survival_by_class = df2.groupby(['Pclass', 'Age_category'])['Survived'].mean().reset_index()
print(age_survival_by_class)
# Out:
#    Pclass Age_category  Survived
# 0       1       Adulto  0.635468
# 1       1      Anciano  0.000000
# 2       1         Niño  0.875000
# 3       2       Adulto  0.384106
# 4       2      Anciano  0.000000
# 5       2         Niño  0.935484
# 6       3       Adulto  0.219512
# 7       3      Anciano  0.000000
# 8       3         Niño  0.371795

# %%
# grafica la relacion de la clase social y la categoria de edad con la probabilidad de supervivencia
plt.figure(figsize=(10, 6))
sns.barplot(data=age_survival_by_class, x='Age_category', y='Survived', hue='Pclass', ci=None)
# Out:
# /var/folders/rs/ks5hqkqn4h1g1x9cm5vwy9nr0000gn/T/ipykernel_55613/1289954742.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=age_survival_by_class, x='Age_category', y='Survived', hue='Pclass', ci=None)
# <Axes: xlabel='Age_category', ylabel='Survived'>

# %%
# 4. ¿Existen diferencias en las tasas de supervivencia entre puertos de embarque que no pueden explicarse por diferencias en composición de clase?

embarked_survival_rate = df2.groupby(['Embarked', 'Pclass'])['Survived'].mean().reset_index()
print(embarked_survival_rate)
# Out:
#   Embarked  Pclass  Survived
# 0        C       1  0.694118
# 1        C       2  0.529412
# 2        C       3  0.378788
# 3        Q       1  0.500000
# 4        Q       2  0.666667
# 5        Q       3  0.375000
# 6        S       1  0.582677
# 7        S       2  0.463415
# 8        S       3  0.189802

# %%
# grafica los resultado anterior
plt.figure(figsize=(10, 6))
sns.barplot(data=embarked_survival_rate, x='Embarked', y='Survived', hue='Pclass', ci=None)
plt.title('Tasa de Supervivencia por Puerto de Embarque y Clase')
plt.xlabel('Puerto de Embarque')
plt.ylabel('Tasa de Supervivencia')
plt.legend(title='Clase')
plt.show()
# Out:
# /var/folders/rs/ks5hqkqn4h1g1x9cm5vwy9nr0000gn/T/ipykernel_55613/307066352.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=embarked_survival_rate, x='Embarked', y='Survived', hue='Pclass', ci=None)
